# %% [markdown]
# # Exam INFO284 V21
# **Members: Didrik Krog, Jonas Holtan, Gunnar Gjengedal, Snorre Alvsvåg**
# ## Introduction
# ### The task
# You are supposed to build at least five machine learning models from these data to predict or
# classify one relevant target feature for new data points. You can choose target feature yourself, but
# sales price is perhaps the most suitable. You may also reduce the number of data points somewhat
# by focusing on only specific meaningful parts of the data. Or perhaps you will try dimension
# reduction.
#
# ### Our Approach
# This task can be split into four parts:
# - **Part 1** Data Exploration
# - **Part 2** Data Cleaning
# - **Part 3** Model Building
# - **Part 4** Presentation and Analysation
#
# We will explore our data by conducting a *Exploratory Data Analysis*. Here we will look at the data and make note of important features, non important features, and in general inform ourselves with the data. In part 2, we will generally clean the data, remove empty or unique columns and so on. In part 3 we will start to fit the models, we will also change the data in preparation of each model. And at last we will present the results, and analyze the different approaches we took with out models.
#
# We have chosen two supervised machine learning algorythms:
# - Algorythm 1
# - Algorythm 2
#
# Two unsupervised machine learning algorythms:
# - Algorythm 3
# - Algotythm 4
#
# and one Deep Learnign algorytm:
# - Deep Learning
#
# Moving forward we will start by learing about our data

# %% [markdown]
# ## Part 1: Data Exploration
# As mentioned in the introduction we will be conductin an Exploratory Data Analysis to learn about the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from sklearn.feature_extraction.text import CountVectorizer
df = pd.read_csv("group_task/nyc-rolling-sales.csv")
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# Sjekke hvor mye variablene veier

# %% [markdown]
# ### General
# Lets start by looking at the data:

# %%
df.head(5)
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# 2   39                                  C7   197 EAST 3RD   STREET  ...
# 3   21                                  C4     154 EAST 7TH STREET  ...
# 4   55                                  C2  301 EAST 10TH   STREET  ...
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                 5                 0            5              1633
# 1                28                 3           31              4616
# 2                16                 1           17              2212
# 3                10                 0           10              2272
# 4                 6                 0            6              2369
#
#    GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0               6440       1900                         2
# 1              18690       1900                         2
# 2               7803       1900                         2
# 3               6794       1913                         2
# 4               4615       1900                         2
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                              C2     6625000  2017-07-19 00:00:00
# 1                              C7         -    2016-12-14 00:00:00
# 2                              C7         -    2016-12-09 00:00:00
# 3                              C4     3936272  2016-09-23 00:00:00
# 4                              C2     8000000  2016-11-17 00:00:00
#
# [5 rows x 22 columns]

# %%
df.tail(5)
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84543        8409        5      WOODROW
# 84544        8410        5      WOODROW
# 84545        8411        5      WOODROW
# 84546        8412        5      WOODROW
# 84547        8413        5      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 84543   7349   34                                  B9          37 QUAIL LANE
# 84544   7349   78                                  B9       32 PHEASANT LANE
# 84545   7351   60                                  B2       49 PITNEY AVENUE
# 84546   7100   28                                  K6  2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9      155 CLAY PIT ROAD
#
#        ... RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 84543  ...                 2                 0            2              2400
# 84544  ...                 2                 0            2              2498
# 84545  ...                 2                 0            2              4000
# 84546  ...                 0                 7            7            208033
# 84547  ...                 0                 1            1             10796
#
#        GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 84543               2575       1998                         1
# 84544               2377       1998                         1
# 84545               1496       1925                         1
# 84546              64117       2001                         4
# 84547               2400       2006                         4
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 84543                              B9      450000  2016-11-28 00:00:00
# 84544                              B9      550000  2017-04-21 00:00:00
# 84545                              B2      460000  2017-07-05 00:00:00
# 84546                              K6    11693337  2016-12-21 00:00:00
# 84547                              P9       69300  2016-10-27 00:00:00
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
#  12  RESIDENTIAL UNITS               84548 non-null  int64
#  13  COMMERCIAL UNITS                84548 non-null  int64
#  14  TOTAL UNITS                     84548 non-null  int64
#  15  LAND SQUARE FEET                84548 non-null  object
#  16  GROSS SQUARE FEET               84548 non-null  object
#  17  YEAR BUILT                      84548 non-null  int64
#  18  TAX CLASS AT TIME OF SALE       84548 non-null  int64
#  19  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  20  SALE PRICE                      84548 non-null  object
#  21  SALE DATE                       84548 non-null  object
# dtypes: int64(10), object(12)
# memory usage: 14.2+ MB

# %% [markdown]
# From this we can learn the basics, there are 22 features where 10 are integers, and 12 are objects. At first glance were curious about what Unnamed : 0, so we will take a closer look at this in a bit, further Building Class Category is a categorical number with the name attatched, this could be made into an int, with a dictionary explaining what the numbers mean. Its questionable if this directly correlates with Building class, so this will also be investigated. Lets start by looking at Unnamed.

# %%
df["Unnamed: 0"].describe()
# Out:
# count    84548.000000
# mean     10344.359878
# std       7151.779436
# min          4.000000
# 25%       4231.000000
# 50%       8942.000000
# 75%      15987.250000
# max      26739.000000
# Name: Unnamed: 0, dtype: float64

# %%
df["Unnamed: 0"].value_counts()
# Out:
# 2049     5
# 478      5
# 350      5
# 2399     5
# 4508     5
#         ..
# 25332    1
# 25591    1
# 24422    1
# 26028    1
# 25278    1
# Name: Unnamed: 0, Length: 26736, dtype: int64

# %% [markdown]
# It is not Uniqe, but it seems to not give anything of value to an algorythm, There are 26736 different options and rows share their value with at most 5 others.

# %% [markdown]
# Now to look at our building class Category:

# %%
df["BUILDING CLASS CATEGORY"].describe()
# Out:
# count                                           84548
# unique                                             47
# top       01 ONE FAMILY DWELLINGS
# freq                                            18235
# Name: BUILDING CLASS CATEGORY, dtype: object

# %%
df["BUILDING CLASS AT PRESENT"].describe()
# Out:
# count     84548
# unique      167
# top          D4
# freq      12663
# Name: BUILDING CLASS AT PRESENT, dtype: object

# %% [markdown]
# **These are not the same.**
#
# We move on to look at NULL values both in the set itself and in the induvidual columns:

# %%
df.isnull().any()
# Out:
# Unnamed: 0                        False
# BOROUGH                           False
# NEIGHBORHOOD                      False
# BUILDING CLASS CATEGORY           False
# TAX CLASS AT PRESENT              False
# BLOCK                             False
# LOT                               False
# EASE-MENT                         False
# BUILDING CLASS AT PRESENT         False
# ADDRESS                           False
# APARTMENT NUMBER                  False
# ZIP CODE                          False
# RESIDENTIAL UNITS                 False
# COMMERCIAL UNITS                  False
# TOTAL UNITS                       False
# LAND SQUARE FEET                  False
# GROSS SQUARE FEET                 False
# YEAR BUILT                        False
# TAX CLASS AT TIME OF SALE         False
# BUILDING CLASS AT TIME OF SALE    False
# SALE PRICE                        False
# SALE DATE                         False
# dtype: bool

# %%
print("Percentage null or na values in Dataset")
((df.isnull() | df.isna()).sum() * 100 / df.index.size).round(2)
# Out:
# Percentage null or na values in Dataset
# Unnamed: 0                        0.0
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# As it stands none of our two functions gives us any warnings, everything is there, and there are no null values. As it is its not wrong or correct, there are empty values in our dataset, but they are represented differently as shown under:

# %%
i = 0
for col in df.columns.tolist():
    print(f'---------------------------\n{col}')
    print(df[col].value_counts())
# Out:
# ---------------------------
# Unnamed: 0
# 2049     5
# 478      5
# 350      5
# 2399     5
# 4508     5
#         ..
# 25332    1
# 25591    1
# 24422    1
# 26028    1
# 25278    1
# Name: Unnamed: 0, Length: 26736, dtype: int64
# ---------------------------
# BOROUGH
# 4    26736
# 3    24047
# 1    18306
# 5     8410
# 2     7049
# Name: BOROUGH, dtype: int64
# ---------------------------
# NEIGHBORHOOD
# FLUSHING-NORTH              3068
# UPPER EAST SIDE (59-79)     1736
# UPPER EAST SIDE (79-96)     1590
# UPPER WEST SIDE (59-79)     1439
# BEDFORD STUYVESANT          1436
#                             ...
# VAN CORTLANDT PARK             2
# EAST RIVER                     1
# CITY ISLAND-PELHAM STRIP       1
# BRONX PARK                     1
# PELHAM BAY                     1
# Name: NEIGHBORHOOD, Length: 254, dtype: int64
# ---------------------------
# BUILDING CLASS CATEGORY
# 01 ONE FAMILY DWELLINGS                         18235
# 02 TWO FAMILY DWELLINGS                         15828
# 13 CONDOS - ELEVATOR APARTMENTS                 12989
# 10 COOPS - ELEVATOR APARTMENTS                  12902
# 03 THREE FAMILY DWELLINGS                        4384
# 07 RENTALS - WALKUP APARTMENTS                   3466
# 09 COOPS - WALKUP APARTMENTS                     2767
# 04 TAX CLASS 1 CONDOS                            1656
# 44 CONDO PARKING                                 1441
# 15 CONDOS - 2-10 UNIT RESIDENTIAL                1281
# 05 TAX CLASS 1 VACANT LAND                       1248
# 17 CONDO COOPS                                   1201
# 22 STORE BUILDINGS                                935
# 12 CONDOS - WALKUP APARTMENTS                     926
# 14 RENTALS - 4-10 UNIT                            671
# 29 COMMERCIAL GARAGES                             587
# 43 CONDO OFFICE BUILDINGS                         475
# 31 COMMERCIAL VACANT LAND                         463
# 08 RENTALS - ELEVATOR APARTMENTS                  382
# 47 CONDO NON-BUSINESS STORAGE                     377
# 21 OFFICE BUILDINGS                               350
# 30 WAREHOUSES                                     326
# 45 CONDO HOTELS                                   211
# 27 FACTORIES                                      201
# 06 TAX CLASS 1 - OTHER                            182
# 41 TAX CLASS 4 - OTHER                            158
# 46 CONDO STORE BUILDINGS                          154
# 26 OTHER HOTELS                                   114
# 37 RELIGIOUS FACILITIES                           100
# 16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT         96
# 33 EDUCATIONAL FACILITIES                          69
# 32 HOSPITAL AND HEALTH FACILITIES                  59
# 48 CONDO TERRACES/GARDENS/CABANAS                  47
# 23 LOFT BUILDINGS                                  46
# 11A CONDO-RENTALS                                  43
# 35 INDOOR PUBLIC AND CULTURAL FACILITIES           32
# 49 CONDO WAREHOUSES/FACTORY/INDUS                  30
# 28 COMMERCIAL CONDOS                               30
# 38 ASYLUMS AND HOMES                               25
# 36 OUTDOOR RECREATIONAL FACILITIES                 14
# 42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC          13
# 34 THEATRES                                        12
# 25 LUXURY HOTELS                                   12
# 18 TAX CLASS 3 - UNTILITY PROPERTIES                4
# 11 SPECIAL CONDO BILLING LOTS                       2
# 39 TRANSPORTATION FACILITIES                        2
# 40 SELECTED GOVERNMENTAL FACILITIES                 2
# Name: BUILDING CLASS CATEGORY, dtype: int64
# ---------------------------
# TAX CLASS AT PRESENT
# 1     38633
# 2     30919
# 4      6140
# 2A     2521
# 2C     1915
# 1A     1444
# 1B     1234
# 2B      814
#         738
# 1C      186
# 3         4
# Name: TAX CLASS AT PRESENT, dtype: int64
# ---------------------------
# BLOCK
# 5066     404
# 16       255
# 2135     211
# 4978     187
# 1171     181
#         ...
# 9513       1
# 15658      1
# 11624      1
# 9577       1
# 2047       1
# Name: BLOCK, Length: 11566, dtype: int64
# ---------------------------
# LOT
# 1       4125
# 20       983
# 12       972
# 40       935
# 23       911
#         ...
# 2097       1
# 801        1
# 2848       1
# 4771       1
# 3224       1
# Name: LOT, Length: 2627, dtype: int64
# ---------------------------
# EASE-MENT
#      84548
# Name: EASE-MENT, dtype: int64
# ---------------------------
# BUILDING CLASS AT PRESENT
# D4    12663
# R4    12482
# A1     6753
# A5     5683
# B2     4923
#       ...
# Z7        1
# P7        1
# Y1        1
# CM        1
# I3        1
# Name: BUILDING CLASS AT PRESENT, Length: 167, dtype: int64
# ---------------------------
# ADDRESS
# 131-05 40TH   ROAD           210
# 429 KENT AVENUE              158
# 169 WEST 95TH   STREET       153
# 131-03 40TH   ROAD           147
# 265 STATE STREET             127
#                             ...
# 160 RIVERSIDE DRIVE, 7B        1
# 212-07 75TH AVENUE, 5-O        1
# 369 PARK PLACE                 1
# 641 41ST   STREET, 2B          1
# 60 EAST 8TH   STREET, 33B      1
# Name: ADDRESS, Length: 67563, dtype: int64
# ---------------------------
# APARTMENT NUMBER
#          65496
# 4          298
# 3A         295
# 2          275
# 3B         275
#          ...
# CAB1         1
# PH 2H        1
# ST-20        1
# G1/G2        1
# G16E         1
# Name: APARTMENT NUMBER, Length: 3989, dtype: int64
# ---------------------------
# ZIP CODE
# 10314    1687
# 11354    1384
# 11201    1324
# 11235    1312
# 11234    1165
#          ...
# 10105       5
# 10803       1
# 11430       1
# 10167       1
# 10281       1
# Name: ZIP CODE, Length: 186, dtype: int64
# ---------------------------
# RESIDENTIAL UNITS
# 1      34722
# 0      24783
# 2      16049
# 3       4608
# 4       1346
#        ...
# 335        1
# 271        1
# 369        1
# 143        1
# 127        1
# Name: RESIDENTIAL UNITS, Length: 176, dtype: int64
# ---------------------------
# COMMERCIAL UNITS
# 0       79429
# 1        3558
# 2         817
# 3         259
# 4         137
# 5          74
# 6          70
# 7          31
# 8          26
# 9          20
# 10         17
# 12         12
# 15         11
# 11         10
# 14          6
# 17          6
# 13          4
# 20          4
# 254         4
# 35          4
# 19          3
# 42          3
# 18          3
# 22          3
# 126         2
# 436         2
# 26          2
# 422         2
# 16          2
# 25          2
# 56          1
# 184         1
# 59          1
# 55          1
# 52          1
# 51          1
# 49          1
# 172         1
# 62          1
# 23          1
# 38          1
# 34          1
# 32          1
# 31          1
# 30          1
# 28          1
# 91          1
# 27          1
# 24          1
# 21          1
# 2261        1
# 147         1
# 73          1
# 67          1
# 318         1
# Name: COMMERCIAL UNITS, dtype: int64
# ---------------------------
# TOTAL UNITS
# 1      38356
# 0      19762
# 2      15914
# 3       5412
# 4       1498
#        ...
# 93         1
# 92         1
# 155        1
# 538        1
# 127        1
# Name: TOTAL UNITS, Length: 192, dtype: int64
# ---------------------------
# LAND SQUARE FEET
#  -       26252
# 0        10326
# 2000      3919
# 2500      3470
# 4000      3044
#          ...
# 8911         1
# 15158        1
# 4944         1
# 4254         1
# 4239         1
# Name: LAND SQUARE FEET, Length: 6062, dtype: int64
# ---------------------------
# GROSS SQUARE FEET
#  -       27612
# 0        11417
# 2400       386
# 1800       361
# 2000       359
#          ...
# 16655        1
# 78496        1
# 53550        1
# 22275        1
# 8963         1
# Name: GROSS SQUARE FEET, Length: 5691, dtype: int64
# ---------------------------
# YEAR BUILT
# 0       6970
# 1920    6045
# 1930    5043
# 1925    4312
# 1910    3585
#         ...
# 1826       1
# 1829       1
# 1855       1
# 1832       1
# 1849       1
# Name: YEAR BUILT, Length: 158, dtype: int64
# ---------------------------
# TAX CLASS AT TIME OF SALE
# 1    41533
# 2    36726
# 4     6285
# 3        4
# Name: TAX CLASS AT TIME OF SALE, dtype: int64
# ---------------------------
# BUILDING CLASS AT TIME OF SALE
# R4    12989
# D4    12666
# A1     6751
# A5     5671
# B2     4918
#       ...
# HH        1
# M2        1
# P7        1
# CM        1
# I3        1
# Name: BUILDING CLASS AT TIME OF SALE, Length: 166, dtype: int64
# ---------------------------
# SALE PRICE
#  -         14561
# 0          10228
# 10           766
# 450000       427
# 550000       416
#            ...
# 650750         1
# 6696625        1
# 2579830        1
# 3103626        1
# 633163         1
# Name: SALE PRICE, Length: 10008, dtype: int64
# ---------------------------
# SALE DATE
# 2017-06-29 00:00:00    544
# 2017-06-15 00:00:00    530
# 2016-12-22 00:00:00    527
# 2017-05-25 00:00:00    511
# 2016-10-06 00:00:00    508
#                       ...
# 2017-07-09 00:00:00      2
# 2016-11-27 00:00:00      2
# 2017-01-08 00:00:00      2
# 2017-08-13 00:00:00      1
# 2017-06-04 00:00:00      1
# Name: SALE DATE, Length: 364, dtype: int64

# %% [markdown]
# Knowing this one can be forgiven to assume that the dataset uses "-" and " " for empty values, lets run the same function as before but using these as values rather than standard .isna() and .isnull()

# %% [markdown]
# Here we can see that 14561 are not numeric, these are the " - ", or in our case, NULL values. We can change them:

# %%
for col in df.columns.tolist():
    df.loc[df[col] == "", col] = None

print("Percentage null or na values in Dataset")
((df.isnull() | df.isna()).sum() * 100 / df.index.size).round(2)
# Out:
# Percentage null or na values in Dataset
# Unnamed: 0                        0.0
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %%
test_df = df.replace(' ', np.nan)
test_df = test_df.replace(' -  ', np.nan)

# %%
test_df["SALE PRICE"].value_counts()
# Out:
# 0           10228
# 10            766
# 450000        427
# 550000        416
# 650000        414
#             ...
# 42420000        1
# 1168750         1
# 2064000         1
# 436610          1
# 289700          1
# Name: SALE PRICE, Length: 10007, dtype: int64

# %%
test_df = test_df.replace('0', np.nan)

# %%
test_df["SALE PRICE"].value_counts()
# Out:
# 10         766
# 450000     427
# 550000     416
# 650000     414
# 600000     409
#           ...
# 650750       1
# 6696625      1
# 2579830      1
# 3103626      1
# 5825000      1
# Name: SALE PRICE, Length: 10006, dtype: int64

# %%
test_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BOROUGH, NEIGHBORHOOD, BUILDING CLASS CATEGORY, TAX CLASS AT PRESENT, BLOCK, LOT, EASE-MENT, BUILDING CLASS AT PRESENT, ADDRESS, APARTMENT NUMBER, ZIP CODE, RESIDENTIAL UNITS, COMMERCIAL UNITS, TOTAL UNITS, LAND SQUARE FEET, GROSS SQUARE FEET, YEAR BUILT, TAX CLASS AT TIME OF SALE, BUILDING CLASS AT TIME OF SALE, SALE PRICE, SALE DATE]
# Index: []
#
# [0 rows x 22 columns]

# %%
print("Percentage null or na values in Dataset\n-------------------------------------")
((test_df.isnull() | test_df.isna()).sum() * 100 / test_df.index.size).round(2)
# Out:
# Percentage null or na values in Dataset
# -------------------------------------
# Unnamed: 0                          0.00
# BOROUGH                             0.00
# NEIGHBORHOOD                        0.00
# BUILDING CLASS CATEGORY             0.00
# TAX CLASS AT PRESENT                0.87
# BLOCK                               0.00
# LOT                                 0.00
# EASE-MENT                         100.00
# BUILDING CLASS AT PRESENT           0.87
# ADDRESS                             0.00
# APARTMENT NUMBER                   77.47
# ZIP CODE                            0.00
# RESIDENTIAL UNITS                   0.00
# COMMERCIAL UNITS                    0.00
# TOTAL UNITS                         0.00
# LAND SQUARE FEET                   43.26
# GROSS SQUARE FEET                  46.16
# YEAR BUILT                          0.00
# TAX CLASS AT TIME OF SALE           0.00
# BUILDING CLASS AT TIME OF SALE      0.00
# SALE PRICE                         29.32
# SALE DATE                           0.00
# dtype: float64

# %%
la = df["SALE PRICE"].str.isnumeric()

# %%
la.value_counts()
# Out:
# True     69987
# False    14561
# Name: SALE PRICE, dtype: int64

# %% [markdown]
# Unnamed, Useless
#
# BOROUGH, BLOCK, LOT, Adress, Apartment number & Zipcode: Either too generalized or too speciif or supersided by Neighborhood
#
# Easement: Useless
#
# BUILDING CLASS AT PRESENT, TAX CLASS AT PRESENT: Supercededed by their "time of sale" Counterpart.
#
# Total Units: Represented within Residental and Commercial Units
# > Check for res + com = Total

# %%
l = df["TOTAL UNITS"]
r = df["RESIDENTIAL UNITS"]
c = df["COMMERCIAL UNITS"]


print(len(l),len(r),len(c))
# Out:
# 84548 84548 84548

# %% [markdown]
# Housing price is distributed
#
# Correlation

# %%
new_df= df.drop(["ADDRESS","Unnamed: 0", "APARTMENT NUMBER", "ZIP CODE",
               "EASE-MENT","BUILDING CLASS AT PRESENT"], axis = 1)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  float64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  float64
#  5   LOT                             84548 non-null  float64
#  6   RESIDENTIAL UNITS               84548 non-null  float64
#  7   COMMERCIAL UNITS                84548 non-null  float64
#  8   TOTAL UNITS                     84548 non-null  float64
#  9   LAND SQUARE FEET                84548 non-null  object
#  10  GROSS SQUARE FEET               84548 non-null  object
#  11  YEAR BUILT                      84548 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       84548 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  14  SALE PRICE                      84548 non-null  object
#  15  SALE DATE                       84548 non-null  object
# dtypes: float64(8), object(8)
# memory usage: 10.3+ MB

# %%
new_df = new_df.replace(' ', np.nan)
new_df = new_df.replace(' -  ', np.nan)

print("Percentage null or na values in Dataset\n-------------------------------------")
((new_df.isnull() | new_df.isna()).sum() * 100 / new_df.index.size).round(2)
# Out:
# Percentage null or na values in Dataset
# -------------------------------------
# BOROUGH                            0.00
# NEIGHBORHOOD                       0.00
# BUILDING CLASS CATEGORY            0.00
# TAX CLASS AT PRESENT               0.87
# BLOCK                              0.00
# LOT                                0.00
# RESIDENTIAL UNITS                  0.00
# COMMERCIAL UNITS                   0.00
# TOTAL UNITS                        0.00
# LAND SQUARE FEET                  31.05
# GROSS SQUARE FEET                 32.66
# YEAR BUILT                         0.00
# TAX CLASS AT TIME OF SALE          0.00
# BUILDING CLASS AT TIME OF SALE     0.00
# SALE PRICE                        17.22
# SALE DATE                          0.00
# dtype: float64

# %%
new_df=new_df.dropna()

# %% [markdown]
# ### Checking types and evaluati

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47892 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         47892 non-null  float64
#  1   NEIGHBORHOOD                    47892 non-null  object
#  2   BUILDING CLASS CATEGORY         47892 non-null  object
#  3   TAX CLASS AT PRESENT            47892 non-null  object
#  4   BLOCK                           47892 non-null  float64
#  5   LOT                             47892 non-null  float64
#  6   RESIDENTIAL UNITS               47892 non-null  float64
#  7   COMMERCIAL UNITS                47892 non-null  float64
#  8   TOTAL UNITS                     47892 non-null  float64
#  9   LAND SQUARE FEET                47892 non-null  object
#  10  GROSS SQUARE FEET               47892 non-null  object
#  11  YEAR BUILT                      47892 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       47892 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  47892 non-null  object
#  14  SALE PRICE                      47892 non-null  object
#  15  SALE DATE                       47892 non-null  object
# dtypes: float64(8), object(8)
# memory usage: 6.2+ MB

# %% [markdown]
# Seeing as theres 10228 counts of 0 in salesprice we drop these, as well as the few instances of 10 dollar amounts:

# %%
new_df["SALE PRICE"] = new_df["SALE PRICE"].astype(float)

# %%
new_df["SALE PRICE"].value_counts()
# Out:
# 0.0          10148
# 10.0           651
# 650000.0       335
# 600000.0       323
# 450000.0       322
#              ...
# 529900.0         1
# 2615270.0        1
# 2116279.0        1
# 425369.0         1
# 2537000.0        1
# Name: SALE PRICE, Length: 6132, dtype: int64

# %%
new_df = new_df[new_df['SALE PRICE'] > 20]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36979 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         36979 non-null  float64
#  1   NEIGHBORHOOD                    36979 non-null  object
#  2   BUILDING CLASS CATEGORY         36979 non-null  object
#  3   TAX CLASS AT PRESENT            36979 non-null  object
#  4   BLOCK                           36979 non-null  float64
#  5   LOT                             36979 non-null  float64
#  6   RESIDENTIAL UNITS               36979 non-null  float64
#  7   COMMERCIAL UNITS                36979 non-null  float64
#  8   TOTAL UNITS                     36979 non-null  float64
#  9   LAND SQUARE FEET                36979 non-null  object
#  10  GROSS SQUARE FEET               36979 non-null  object
#  11  YEAR BUILT                      36979 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       36979 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  36979 non-null  object
#  14  SALE PRICE                      36979 non-null  float64
#  15  SALE DATE                       36979 non-null  object
# dtypes: float64(9), object(7)
# memory usage: 4.8+ MB

# %%
new_df["SALE PRICE"].value_counts()
# Out:
# 650000.0      335
# 600000.0      323
# 450000.0      322
# 550000.0      317
# 700000.0      315
#              ...
# 1105800.0       1
# 2559999.0       1
# 23738428.0      1
# 384071.0        1
# 5016310.0       1
# Name: SALE PRICE, Length: 6124, dtype: int64

# %%
plt.hist(new_df['SALE PRICE'], bins = 150 , histtype = 'step' )
# Out:
# (array([3.6622e+04, 1.9800e+02, 5.6000e+01, 2.6000e+01, 1.4000e+01,
#         1.3000e+01, 9.0000e+00, 6.0000e+00, 7.0000e+00, 7.0000e+00,
#         5.0000e+00, 2.0000e+00, 1.0000e+00, 2.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([1.00000000e+02, 1.47334327e+07, 2.94667653e+07, 4.42000980e+07,
#         5.89334307e+07, 7.36667633e+07, 8.84000960e+07, 1.03133429e+08,
#         1.17866761e+08, 1.32600094e+08, 1.47333427e+08, 1.62066759e+08,
#         1.76800092e+08, 1.91533425e+08, 2.06266757e+08, 2.21000090e+08,
#         2.35733423e+08, 2.50466755e+08, 2.65200088e+08, 2.79933421e+08,
#         2.94666753e+08, 3.09400086e+08, 3.24133419e+08, 3.38866751e+08,
#         3.53600084e+08, 3.68333417e+08, 3.83066749e+08, 3.97800082e+08,
#         4.12533415e+08, 4.27266747e+08, 4.42000080e+08, 4.56733413e+08,
#         4.71466745e+08, 4.86200078e+08, 5.00933411e+08, 5.15666743e+08,
#         5.30400076e+08, 5.45133409e+08, 5.59866741e+08, 5.74600074e+08,
#         5.89333407e+08, 6.04066739e+08, 6.18800072e+08, 6.33533405e+08,
#         6.48266737e+08, 6.63000070e+08, 6.77733403e+08, 6.92466735e+08,
#         7.07200068e+08, 7.21933401e+08, 7.36666733e+08, 7.51400066e+08,
#         7.66133399e+08, 7.80866731e+08, 7.95600064e+08, 8.10333397e+08,
#         8.25066729e+08, 8.39800062e+08, 8.54533395e+08, 8.69266727e+08,
#         8.84000060e+08, 8.98733393e+08, 9.13466725e+08, 9.28200058e+08,
#         9.42933391e+08, 9.57666723e+08, 9.72400056e+08, 9.87133389e+08,
#         1.00186672e+09, 1.01660005e+09, 1.03133339e+09, 1.04606672e+09,
#         1.06080005e+09, 1.07553338e+09, 1.09026672e+09, 1.10500005e+09,
#         1.11973338e+09, 1.13446672e+09, 1.14920005e+09, 1.16393338e+09,
#         1.17866671e+09, 1.19340005e+09, 1.20813338e+09, 1.22286671e+09,
#         1.23760004e+09, 1.25233338e+09, 1.26706671e+09, 1.28180004e+09,
#         1.29653337e+09, 1.31126671e+09, 1.32600004e+09, 1.34073337e+09,
#         1.35546671e+09, 1.37020004e+09, 1.38493337e+09, 1.39966670e+09,
#         1.41440004e+09, 1.42913337e+09, 1.44386670e+09, 1.45860003e+09,
#         1.47333337e+09, 1.48806670e+09, 1.50280003e+09, 1.51753336e+09,
#         1.53226670e+09, 1.54700003e+09, 1.56173336e+09, 1.57646670e+09,
#         1.59120003e+09, 1.60593336e+09, 1.62066669e+09, 1.63540003e+09,
#         1.65013336e+09, 1.66486669e+09, 1.67960002e+09, 1.69433336e+09,
#         1.70906669e+09, 1.72380002e+09, 1.73853335e+09, 1.75326669e+09,
#         1.76800002e+09, 1.78273335e+09, 1.79746669e+09, 1.81220002e+09,
#         1.82693335e+09, 1.84166668e+09, 1.85640002e+09, 1.87113335e+09,
#         1.88586668e+09, 1.90060001e+09, 1.91533335e+09, 1.93006668e+09,
#         1.94480001e+09, 1.95953334e+09, 1.97426668e+09, 1.98900001e+09,
#         2.00373334e+09, 2.01846668e+09, 2.03320001e+09, 2.04793334e+09,
#         2.06266667e+09, 2.07740001e+09, 2.09213334e+09, 2.10686667e+09,
#         2.12160000e+09, 2.13633334e+09, 2.15106667e+09, 2.16580000e+09,
#         2.18053333e+09, 2.19526667e+09, 2.21000000e+09]),
#  [<matplotlib.patches.Polygon at 0x7fd4bf54ddc0>])

# %% [markdown]
# As seen the distrubution is all messed up due to outlier, we remove these, including only values within three standard deviations of the mean

# %%
new_df = new_df[new_df['SALE PRICE'] > (np.mean(new_df['SALE PRICE'])-
                                          np.std(new_df['SALE PRICE'], 
                                                 ddof = 1))]
new_df = new_df[new_df['SALE PRICE'] < np.mean(new_df['SALE PRICE'])+ 
                                         np.std(new_df['SALE PRICE'], 

                                                ddof = 1)]

# %%
plt.hist(new_df['SALE PRICE'], bins = 150 , histtype = 'step' )
# Out:
# (array([1.437e+03, 2.167e+03, 3.318e+03, 4.426e+03, 5.108e+03, 4.147e+03,
#         3.326e+03, 2.519e+03, 2.477e+03, 7.880e+02, 9.440e+02, 8.770e+02,
#         7.200e+02, 5.150e+02, 3.960e+02, 3.080e+02, 2.350e+02, 2.760e+02,
#         1.610e+02, 1.680e+02, 1.420e+02, 1.390e+02, 1.500e+02, 1.080e+02,
#         8.700e+01, 8.700e+01, 7.800e+01, 6.100e+01, 4.500e+01, 8.000e+01,
#         4.100e+01, 6.200e+01, 4.400e+01, 6.300e+01, 4.800e+01, 4.500e+01,
#         3.200e+01, 1.900e+01, 2.900e+01, 2.500e+01, 3.200e+01, 1.900e+01,
#         2.000e+01, 1.300e+01, 4.300e+01, 2.600e+01, 1.600e+01, 2.200e+01,
#         1.600e+01, 3.300e+01, 1.900e+01, 2.200e+01, 1.600e+01, 2.900e+01,
#         1.400e+01, 1.500e+01, 8.000e+00, 1.000e+01, 1.600e+01, 1.400e+01,
#         2.000e+01, 1.000e+01, 2.300e+01, 9.000e+00, 2.000e+01, 8.000e+00,
#         1.400e+01, 1.500e+01, 1.200e+01, 1.000e+01, 5.000e+00, 1.600e+01,
#         6.000e+00, 7.000e+00, 8.000e+00, 3.000e+00, 1.200e+01, 6.000e+00,
#         7.000e+00, 8.000e+00, 1.300e+01, 6.000e+00, 8.000e+00, 1.200e+01,
#         7.000e+00, 1.200e+01, 0.000e+00, 5.000e+00, 1.100e+01, 1.500e+01,
#         6.000e+00, 9.000e+00, 7.000e+00, 3.000e+00, 1.400e+01, 5.000e+00,
#         6.000e+00, 2.000e+00, 1.200e+01, 6.000e+00, 7.000e+00, 6.000e+00,
#         9.000e+00, 3.000e+00, 7.000e+00, 6.000e+00, 4.000e+00, 9.000e+00,
#         4.000e+00, 6.000e+00, 4.000e+00, 1.100e+01, 4.000e+00, 0.000e+00,
#         4.000e+00, 5.000e+00, 8.000e+00, 2.000e+00, 3.000e+00, 1.000e+00,
#         6.000e+00, 4.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+01,
#         2.000e+00, 5.000e+00, 0.000e+00, 7.000e+00, 0.000e+00, 3.000e+00,
#         1.000e+00, 4.000e+00, 1.200e+01, 2.000e+00, 5.000e+00, 0.000e+00,
#         5.000e+00, 1.000e+00, 1.000e+00, 4.000e+00, 0.000e+00, 5.000e+00,
#         1.000e+00, 2.000e+00, 1.000e+00, 2.000e+00, 2.000e+00, 1.000e+00]),
#  array([1.0000000e+02, 1.1176600e+05, 2.2343200e+05, 3.3509800e+05,
#         4.4676400e+05, 5.5843000e+05, 6.7009600e+05, 7.8176200e+05,
#         8.9342800e+05, 1.0050940e+06, 1.1167600e+06, 1.2284260e+06,
#         1.3400920e+06, 1.4517580e+06, 1.5634240e+06, 1.6750900e+06,
#         1.7867560e+06, 1.8984220e+06, 2.0100880e+06, 2.1217540e+06,
#         2.2334200e+06, 2.3450860e+06, 2.4567520e+06, 2.5684180e+06,
#         2.6800840e+06, 2.7917500e+06, 2.9034160e+06, 3.0150820e+06,
#         3.1267480e+06, 3.2384140e+06, 3.3500800e+06, 3.4617460e+06,
#         3.5734120e+06, 3.6850780e+06, 3.7967440e+06, 3.9084100e+06,
#         4.0200760e+06, 4.1317420e+06, 4.2434080e+06, 4.3550740e+06,
#         4.4667400e+06, 4.5784060e+06, 4.6900720e+06, 4.8017380e+06,
#         4.9134040e+06, 5.0250700e+06, 5.1367360e+06, 5.2484020e+06,
#         5.3600680e+06, 5.4717340e+06, 5.5834000e+06, 5.6950660e+06,
#         5.8067320e+06, 5.9183980e+06, 6.0300640e+06, 6.1417300e+06,
#         6.2533960e+06, 6.3650620e+06, 6.4767280e+06, 6.5883940e+06,
#         6.7000600e+06, 6.8117260e+06, 6.9233920e+06, 7.0350580e+06,
#         7.1467240e+06, 7.2583900e+06, 7.3700560e+06, 7.4817220e+06,
#         7.5933880e+06, 7.7050540e+06, 7.8167200e+06, 7.9283860e+06,
#         8.0400520e+06, 8.1517180e+06, 8.2633840e+06, 8.3750500e+06,
#         8.4867160e+06, 8.5983820e+06, 8.7100480e+06, 8.8217140e+06,
#         8.9333800e+06, 9.0450460e+06, 9.1567120e+06, 9.2683780e+06,
#         9.3800440e+06, 9.4917100e+06, 9.6033760e+06, 9.7150420e+06,
#         9.8267080e+06, 9.9383740e+06, 1.0050040e+07, 1.0161706e+07,
#         1.0273372e+07, 1.0385038e+07, 1.0496704e+07, 1.0608370e+07,
#         1.0720036e+07, 1.0831702e+07, 1.0943368e+07, 1.1055034e+07,
#         1.1166700e+07, 1.1278366e+07, 1.1390032e+07, 1.1501698e+07,
#         1.1613364e+07, 1.1725030e+07, 1.1836696e+07, 1.1948362e+07,
#         1.2060028e+07, 1.2171694e+07, 1.2283360e+07, 1.2395026e+07,
#         1.2506692e+07, 1.2618358e+07, 1.2730024e+07, 1.2841690e+07,
#         1.2953356e+07, 1.3065022e+07, 1.3176688e+07, 1.3288354e+07,
#         1.3400020e+07, 1.3511686e+07, 1.3623352e+07, 1.3735018e+07,
#         1.3846684e+07, 1.3958350e+07, 1.4070016e+07, 1.4181682e+07,
#         1.4293348e+07, 1.4405014e+07, 1.4516680e+07, 1.4628346e+07,
#         1.4740012e+07, 1.4851678e+07, 1.4963344e+07, 1.5075010e+07,
#         1.5186676e+07, 1.5298342e+07, 1.5410008e+07, 1.5521674e+07,
#         1.5633340e+07, 1.5745006e+07, 1.5856672e+07, 1.5968338e+07,
#         1.6080004e+07, 1.6191670e+07, 1.6303336e+07, 1.6415002e+07,
#         1.6526668e+07, 1.6638334e+07, 1.6750000e+07]),
#  [<matplotlib.patches.Polygon at 0x7fd4bf6d5f70>])

# %% [markdown]
# we can see saleprice are almost have normal distrubution. There are still extreme values, but that is to be expected, some houses can be extremely costly, this is important to include for diversity in our models.

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36671 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         36671 non-null  float64
#  1   NEIGHBORHOOD                    36671 non-null  object
#  2   BUILDING CLASS CATEGORY         36671 non-null  object
#  3   TAX CLASS AT PRESENT            36671 non-null  object
#  4   BLOCK                           36671 non-null  float64
#  5   LOT                             36671 non-null  float64
#  6   RESIDENTIAL UNITS               36671 non-null  float64
#  7   COMMERCIAL UNITS                36671 non-null  float64
#  8   TOTAL UNITS                     36671 non-null  float64
#  9   LAND SQUARE FEET                36671 non-null  object
#  10  GROSS SQUARE FEET               36671 non-null  object
#  11  YEAR BUILT                      36671 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       36671 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  36671 non-null  object
#  14  SALE PRICE                      36671 non-null  float64
#  15  SALE DATE                       36671 non-null  object
# dtypes: float64(9), object(7)
# memory usage: 4.8+ MB

# %%
new_df["BUILDING CLASS CATEGORY"]
# Out:
# 0        07 RENTALS - WALKUP APARTMENTS
# 3        07 RENTALS - WALKUP APARTMENTS
# 4        07 RENTALS - WALKUP APARTMENTS
# 6        07 RENTALS - WALKUP APARTMENTS
# 9        08 RENTALS - ELEVATOR APARTMENTS
#                             ...
# 84543    02 TWO FAMILY DWELLINGS
# 84544    02 TWO FAMILY DWELLINGS
# 84545    02 TWO FAMILY DWELLINGS
# 84546    22 STORE BUILDINGS
# 84547    35 INDOOR PUBLIC AND CULTURAL FACILITIES
# Name: BUILDING CLASS CATEGORY, Length: 36671, dtype: object

# %%
BuildingClass_list = new_df["BUILDING CLASS CATEGORY"].tolist()
numerical_list = []
for i in range(len(BuildingClass_list)):
    number = re.sub(r"[^0-9]", "", BuildingClass_list[i])
    if len(number) > 2: number = number[:2]
    number = re.sub(r"\b0", "", number)
    number = int(number)
    numerical_list.append(number)
    
new_df["BUILDING CLASS CATEGORY"] = numerical_list

# %%
new_df["BUILDING CLASS CATEGORY"].value_counts()
# Out:
# 1     12673
# 2      9876
# 10     2862
# 13     2501
# 3      2332
# 7      1714
# 15      744
# 9       555
# 4       523
# 22      462
# 12      376
# 14      323
# 5       243
# 29      233
# 44      167
# 21      166
# 30      155
# 8       113
# 27       98
# 31       86
# 26       78
# 37       61
# 41       40
# 6        34
# 43       32
# 17       31
# 47       27
# 33       24
# 32       22
# 46       20
# 23       17
# 35       14
# 16       14
# 38       13
# 48       11
# 11       10
# 49        9
# 28        3
# 36        2
# 34        2
# 42        2
# 39        1
# 45        1
# 40        1
# Name: BUILDING CLASS CATEGORY, dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36671 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         36671 non-null  float64
#  1   NEIGHBORHOOD                    36671 non-null  object
#  2   BUILDING CLASS CATEGORY         36671 non-null  int64
#  3   TAX CLASS AT PRESENT            36671 non-null  object
#  4   BLOCK                           36671 non-null  float64
#  5   LOT                             36671 non-null  float64
#  6   RESIDENTIAL UNITS               36671 non-null  float64
#  7   COMMERCIAL UNITS                36671 non-null  float64
#  8   TOTAL UNITS                     36671 non-null  float64
#  9   LAND SQUARE FEET                36671 non-null  object
#  10  GROSS SQUARE FEET               36671 non-null  object
#  11  YEAR BUILT                      36671 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       36671 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  36671 non-null  object
#  14  SALE PRICE                      36671 non-null  float64
#  15  SALE DATE                       36671 non-null  object
# dtypes: float64(9), int64(1), object(6)
# memory usage: 4.8+ MB

# %% [markdown]
# Above we are removing off values, e.g

# %%
new_df["LAND SQUARE FEET"] = new_df["LAND SQUARE FEET"].astype(float)

# %%
new_df["GROSS SQUARE FEET"] = new_df["GROSS SQUARE FEET"].astype(float)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36671 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         36671 non-null  float64
#  1   NEIGHBORHOOD                    36671 non-null  object
#  2   BUILDING CLASS CATEGORY         36671 non-null  int64
#  3   TAX CLASS AT PRESENT            36671 non-null  object
#  4   BLOCK                           36671 non-null  float64
#  5   LOT                             36671 non-null  float64
#  6   RESIDENTIAL UNITS               36671 non-null  float64
#  7   COMMERCIAL UNITS                36671 non-null  float64
#  8   TOTAL UNITS                     36671 non-null  float64
#  9   LAND SQUARE FEET                36671 non-null  float64
#  10  GROSS SQUARE FEET               36671 non-null  float64
#  11  YEAR BUILT                      36671 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       36671 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  36671 non-null  object
#  14  SALE PRICE                      36671 non-null  float64
#  15  SALE DATE                       36671 non-null  object
# dtypes: float64(11), int64(1), object(4)
# memory usage: 4.8+ MB

# %%
new_df["SALE DATE"] = pd.to_datetime(new_df["SALE DATE"])

# %%
new_df["SALE DATE"]
# Out:
# 0       2017-07-19
# 3       2016-09-23
# 4       2016-11-17
# 6       2016-09-23
# 9       2016-11-07
#            ...
# 84543   2016-11-28
# 84544   2017-04-21
# 84545   2017-07-05
# 84546   2016-12-21
# 84547   2016-10-27
# Name: SALE DATE, Length: 36671, dtype: datetime64[ns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36671 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         36671 non-null  float64
#  1   NEIGHBORHOOD                    36671 non-null  object
#  2   BUILDING CLASS CATEGORY         36671 non-null  int64
#  3   TAX CLASS AT PRESENT            36671 non-null  object
#  4   BLOCK                           36671 non-null  float64
#  5   LOT                             36671 non-null  float64
#  6   RESIDENTIAL UNITS               36671 non-null  float64
#  7   COMMERCIAL UNITS                36671 non-null  float64
#  8   TOTAL UNITS                     36671 non-null  float64
#  9   LAND SQUARE FEET                36671 non-null  float64
#  10  GROSS SQUARE FEET               36671 non-null  float64
#  11  YEAR BUILT                      36671 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       36671 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  36671 non-null  object
#  14  SALE PRICE                      36671 non-null  float64
#  15  SALE DATE                       36671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(3)
# memory usage: 4.8+ MB

# %% [markdown]
# ### FACTORIZATION TIME

# %%
l = new_df["BUILDING CLASS AT TIME OF SALE"].to_list()
vectorizer = CountVectorizer()
building_class = vectorizer.fit_transform(l).toarray()

# %%
len(building_class[0])
# Out:
# 142

# %%
new_df["BUILDING CLASS AT TIME OF SALE"] = building_class

# %%
new_df["BUILDING CLASS AT TIME OF SALE"].value_counts()
# Out:
# 0    36388
# 1      283
# Name: BUILDING CLASS AT TIME OF SALE, dtype: int64

# %%
new_df["NEIGHBORHOOD"].value_counts()
# Out:
# BEDFORD STUYVESANT          871
# FLUSHING-NORTH              778
# EAST NEW YORK               688
# BOROUGH PARK                601
# SHEEPSHEAD BAY              580
#                            ...
# NEW BRIGHTON-ST. GEORGE       2
# MIDTOWN CBD                   2
# EAST RIVER                    1
# CITY ISLAND-PELHAM STRIP      1
# BRONX PARK                    1
# Name: NEIGHBORHOOD, Length: 247, dtype: int64

# %%
l_1 = []

for l in new_df["NEIGHBORHOOD"]:
    l = re.sub("[^a-zA-Z]+", "", l)
    l_1.append(l)
new_df["NEIGHBORHOOD"] = l_1

# %%
new_df["NEIGHBORHOOD"].value_counts()
# Out:
# BEDFORDSTUYVESANT        871
# FLUSHINGNORTH            778
# EASTNEWYORK              688
# BOROUGHPARK              601
# SHEEPSHEADBAY            580
#                         ...
# FRESHKILLS                 2
# MIDTOWNCBD                 2
# CITYISLANDPELHAMSTRIP      1
# EASTRIVER                  1
# BRONXPARK                  1
# Name: NEIGHBORHOOD, Length: 243, dtype: int64

# %%
l = new_df["NEIGHBORHOOD"].to_list()
vectorizer = CountVectorizer(min_df = 5)
neighboorhood = vectorizer.fit_transform(l).toarray()

# %%
new_df["NEIGHBORHOOD"] = neighboorhood

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36671 entries, 0 to 84547
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         36671 non-null  float64
#  1   NEIGHBORHOOD                    36671 non-null  int64
#  2   BUILDING CLASS CATEGORY         36671 non-null  int64
#  3   TAX CLASS AT PRESENT            36671 non-null  object
#  4   BLOCK                           36671 non-null  float64
#  5   LOT                             36671 non-null  float64
#  6   RESIDENTIAL UNITS               36671 non-null  float64
#  7   COMMERCIAL UNITS                36671 non-null  float64
#  8   TOTAL UNITS                     36671 non-null  float64
#  9   LAND SQUARE FEET                36671 non-null  float64
#  10  GROSS SQUARE FEET               36671 non-null  float64
#  11  YEAR BUILT                      36671 non-null  float64
#  12  TAX CLASS AT TIME OF SALE       36671 non-null  float64
#  13  BUILDING CLASS AT TIME OF SALE  36671 non-null  int64
#  14  SALE PRICE                      36671 non-null  float64
#  15  SALE DATE                       36671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(3), object(1)
# memory usage: 4.8+ MB

# %%
scatter_df = new_df.drop(['SALE PRICE'], axis = 1) 

for col in scatter_df.columns:
    plt.scatter(scatter_df[col], new_df['SALE PRICE'])
    plt.ylabel('Sale price')
    plt.xlabel(col)
    print(plt.show())
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
sns.heatmap(new_df.corr())
# Out:
# <AxesSubplot:>

# %%
new_df= new_df[new_df['GROSS SQUARE FEET'] < 100000]
new_df= new_df[new_df['LAND SQUARE FEET'] < 100000]
new_df= new_df[new_df['TOTAL UNITS'] < 100]
new_df= new_df[new_df['YEAR BUILT'] > 1750]
new_df= new_df[new_df['LOT'] < 4000]

# %%
scatter_df = new_df.drop(['SALE PRICE'], axis = 1) 

for col in scatter_df.columns:
    plt.scatter(scatter_df[col], new_df['SALE PRICE'])
    plt.ylabel('Sale price')
    plt.xlabel(col)
    plt.show()

# %%
import seaborn as sb

fig, ax = plt.subplots(figsize=(11, 9))
# plot heatmap
sb.heatmap(new_df.corr(), cmap="viridis", vmin= 0.1, vmax=1,
           linewidth=0.3, cbar_kws={"shrink": 1})
plt.show()

# %%
plt.figure(figsize=(12, 10))

sns.heatmap(new_df.corr()[(new_df.corr() >= 0.2) | (new_df.corr() <= -0.2)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

arr = new_df.drop(['SALE PRICE'], axis = 1).to_numpy()
X = np.transpose(arr)
arr = new_df['SALE PRICE']
y = np.transpose(arr)
X_train, X_test , y_train, y_test = train_test_split(X ,y , random_state = 0)


lr = LinearRegression().fit(X_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-759814d843e1> in <module>
#       6 arr = new_df['SALE PRICE']
#       7 y = np.transpose(arr)
# ----> 8 X_train, X_test , y_train, y_test = train_test_split(X ,y , random_state = 0)
#       9
#      10
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     297     """
#     298     result = [_make_indexable(X) for X in iterables]
# --> 299     check_consistent_length(*result)
#     300     return result
#     301
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [15, 35046]

# %%
len(new_df)

# %%
len(new_df['SALE PRICE'])

# %%
new_df2 = new_df.drop(['TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE', 'SALE DATE'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

arr = new_df2.drop(['SALE PRICE'], axis = 1).to_numpy()
X = np.transpose(arr)
y = new_df2['SALE PRICE'].to_numpy()
print(X.shape)
y = y.reshape((35046, 1))
y.shape


#X_train, X_test , y_train, y_test = train_test_split(X ,y , random_state = 0)
#lr = LinearRegression().fit(X_train , y_train)
# Out:
# (12, 35046)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-c8fbd2c351cc> in <module>
#      10
#      11
# ---> 12 X_train, X_test , y_train, y_test = train_test_split(X ,y , random_state = 0)
#      13 lr = LinearRegression().fit(X_train , y_train)
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     297     """
#     298     result = [_make_indexable(X) for X in iterables]
# --> 299     check_consistent_length(*result)
#     300     return result
#     301
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [12, 35046]

# %%
new_df2.info()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-05f0688781ae> in <module>
# ----> 1 for l in new_df2.colums:
#       2     l.value_counts()
#
# ~/Documents/machine_learning/machine-learning_284/.venv/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colums'
